# %% [markdown]
# <a href="https://colab.research.google.com/github/1998456/1998456/blob/main/R_Programming(4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FACTOR

# %%
# Statistial Datatype used to store categorical variables;Use factor()function;
gender_vector <- c('Male', 'Female', 'Female', 'Male', 'Male')
gender_factor <- factor(gender_vector)
gender_factor
# Out:
# [1] Male   Female Female Male   Male
# Levels: Female Male

# %% [markdown]
# ## Categorical Variables & Factor Levels

# %%
# Norminal Variable- has no order;
animal_vec <- c('Dog', 'Rabbit', 'Cat', 'Dog', 'Cat')

# Ordinal_Variable- has natural ordering;
temperature_vec <- c('High','Low','High','Low','Medium')

# %%
animal_factor <- factor(animal_vec)
animal_factor
# Out:
# [1] Dog    Rabbit Cat    Dog    Cat
# Levels: Cat Dog Rabbit

# %%
temperature_factor <- factor(temperature_vec)
temperature_factor
# Out:
# [1] High   Low    High   Low    Medium
# Levels: High Low Medium

# %% [markdown]
# ## Factor Level

# %%
# using the function level();
survey_vec <- c('Male', 'Female', 'Female', 'Male', 'Male')
survey_vec <- factor(survey_vec)
survey_vec
# Out:
# [1] Male   Female Female Male   Male
# Levels: Female Male

# %%
level_vec <- levels(survey_vec)

# %%
level_vec
# Out:
# [1] "Female" "Male"

# %%
factor_survey_vec_inv <- factor(survey_vec)
factor_survey_vec_inv
# Out:
# [1] Male   Female Female Male   Male
# Levels: Female Male

# %%
levels(factor_survey_vec_inv) <- c('Male','Female')
factor_survey_vec_inv
# Out:
# [1] Female Male   Male   Female Female
# Levels: Male Female

# %%
survey_vec
# Out:
# [1] Male   Female Female Male   Male
# Levels: Female Male

# %% [markdown]
# ## Summarizing a Factor

# %%
# Using summary() function;
summary(survey_vec)
summary(factor_survey_vec_inv)
# Out:
# Female   Male
#      2      3
#   Male Female
#      2      3

# %% [markdown]
# ## Ordered Factors

# %%
speed_vec <- c('fast','slow','slow','fast','very fast')
speed_vec
# Out:
# [1] "fast"      "slow"      "slow"      "fast"      "very fast"

# %%
factor_speed_vec <- factor(speed_vec,ordered=TRUE, levels = c('slow','fast','very fast'))
factor_speed_vec
# Out:
# [1] fast      slow      slow      fast      very fast
# Levels: slow < fast < very fast

# %%
summary(factor_speed_vec)
# Out:
#      slow      fast very fast
#         2         2         1

# %% [markdown]
# ## Comparing Ordersd vectors

# %%
# Is dataanalyst2 faster than data analyst5;
compare <- factor_speed_vec[2] > factor_speed_vec[5]
compare
# Out:
# [1] FALSE
