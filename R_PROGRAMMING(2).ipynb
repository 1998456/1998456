# %% [markdown]
# <a href="https://colab.research.google.com/github/1998456/1998456/blob/main/R_PROGRAMMING(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## VECTOR

# %%
# Naming a Vector;
A_vector <- c('Dave','Footballer')
names(A_vector) <- c('Name','Profession')

# %%
print(A_vector)
# Out:
#         Name   Profession
#       "Dave" "Footballer"

# %%
days<- c('Mon','Tues','Weds','Thurs','Frid')
names(days) <- c('Day1','Day2','Day3','Day4','Day5')

# %%
print(days)
# Out:
#    Day1    Day2    Day3    Day4    Day5
#   "Mon"  "Tues"  "Weds" "Thurs"  "Frid"

# %% [markdown]
# Arithmetic Calculations

# %%
# Addition;
c(1,2,3) + c(4,5,6)
# Out:
# [1] 5 7 9

# %%
c(1+4,1+6)
# Out:
# [1] 5 7

# %%
# Performing Addition Using Variable Vectors;
a <- c(1,2,3)
b <- c(2,4,5)
c <- a + b

# %%
c
# Out:
# [1] 3 6 8

# %% [markdown]
# VECTOR SELECTION

# %%
COLOR <- c('RED','BLUE','GREEN','BLACK')
COLOR
# Out:
# [1] "RED"   "BLUE"  "GREEN" "BLACK"

# %%
COLOR[4]
# Out:
# [1] "BLACK"

# %%
s_colors <- COLOR[1:2]
s_colors
# Out:
# [1] "RED"  "BLUE"

# %% [markdown]
# SELECTION BY COMPARISON

# %%
# Which is greater;
c(4,5,6) > 5
# Out:
# [1] FALSE FALSE  TRUE
