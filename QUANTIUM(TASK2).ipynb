# %% [markdown]
# <a href="https://colab.research.google.com/github/1998456/1998456/blob/main/QUANTIUM(TASK2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("/content/QVI_data.csv")

# %%
df.head()
# Out:
#    LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0            1000  2018-10-17          1       1         5
# 1            1002  2018-09-16          1       2        58
# 2            1003  2019-03-07          1       3        52
# 3            1003  2019-03-08          1       4       106
# 4            1004  2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0        175
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7        150
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6        210
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0        175
# 4          WW Original Stacked Chips 160g         1        1.9        160
#
#         BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0     NATURAL  YOUNG SINGLES/COUPLES          Premium
# 1         RRD  YOUNG SINGLES/COUPLES       Mainstream
# ...

# %% [markdown]
# ## TOTAL SALES

# %%
tot_sales= sum(df["TOT_SALES"])

# %%
print(tot_sales)
# Out:
# 351935.45000000304

# %% [markdown]
# There's no customer column in the dataset but it could be retrieved from TX_ID because it's unique for every individual

# %%
df.describe()
# Out:
#        LYLTY_CARD_NBR     STORE_NBR        TXN_ID      PROD_NBR      PROD_QTY  \
# count    48855.000000  48855.000000  48855.000000  48855.000000  48855.000000
# mean     27745.755276     27.576420  24956.094975     56.461693      1.873299
# std      15726.046046     15.727747  14398.727749     32.840060      0.377872
# min       1000.000000      1.000000      1.000000      1.000000      1.000000
# 25%      13219.000000     13.000000  12479.500000     28.000000      2.000000
# 50%      28073.000000     28.000000  24966.000000     55.000000      2.000000
# 75%      40291.000000     40.000000  37434.500000     85.000000      2.000000
# max      55232.000000     55.000000  49891.000000    114.000000      5.000000
#
#           TOT_SALES     PACK_SIZE
# count  48855.000000  48855.000000
# mean       7.203673    182.628472
# std        2.592786     64.521303
# min        1.500000     70.000000
# 25%        5.400000    150.000000
# 50%        7.400000    170.000000
# ...

# %% [markdown]
# ## TOTAL CUSTOMER

# %%
Total_customer= 49891

# %% [markdown]
# ## Total Number Of Transaction per Customer

# %%
df.shape
# Out:
# (48855, 12)

# %%
avg_trns= Total_customer/48855

# %%
print(avg_trns)
