# %% [markdown]
# <a href="https://colab.research.google.com/github/1998456/1998456/blob/main/R_PROGRAMMING(Arithmetic_Operation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exponentiation;
2^5
# Out:
# [1] 32

# %%
28%%6
# Out:
# [1] 4

# %% [markdown]
# VARIABLES

# %%
# Assigning 5 to the variable my_apples;
my_apples <- 5
my_apples
# Out:
# [1] 5

# %%
# Adding 2 Variables;
my_oranges <- 6
my_oranges
# Out:
# [1] 6

# %%
fruits <- my_apples + my_oranges
fruits
# Out:
# [1] 11

# %% [markdown]
# Data Types

# %%
numeric <- 42
character <- "forty-two"
logical <- FALSE
Float <- 42.5

# %%
class(numeric)
class(character)
class(logical)
class(Float)
# Out:
# [1] "numeric"
# [1] "character"
# [1] "logical"
# [1] "numeric"

# %% [markdown]
# Vector Creation

# %%
# Use c() function to create vectors;
# Boolean_Vector;
boolean_vector <- c(TRUE,FALSE,TRUE)
boolean_vector
# Out:
# [1]  TRUE FALSE  TRUE

# %%
# Poker Winnings From Mnday to Friday;
poker_vector <- c(140, -50, 20, -120, 240)

# Roulette Winnings from Monday to Friday;
roulette_vector <- c(-24, -50, 100, -350, 10)

# %%
poker_vector
# Out:
# [1]  140  -50   20 -120  240

# %%
roulette_vector
# Out:
# [1]  -24  -50  100 -350   10
